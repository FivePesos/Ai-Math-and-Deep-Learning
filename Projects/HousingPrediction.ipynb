# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

# %%
#load the data set to be analyze; the data set is loaded to the object dataframe named 'df' (this is user-defined)
dataSet = pd.read_csv('C:/Users/johnp/Programming/Artificial Intelligence and Machine Learning/Projects/USA-Housing-Dataset.csv')
df =pd.DataFrame(dataSet)

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-09 00:00:00  3.760000e+05       3.0       2.00         1340
# 1     2014-05-09 00:00:00  8.000000e+05       4.0       3.25         3540
# 2     2014-05-09 00:00:00  2.238888e+06       5.0       6.50         7270
# 3     2014-05-09 00:00:00  3.240000e+05       3.0       2.25          998
# 4     2014-05-10 00:00:00  5.499000e+05       5.0       2.75         3060
# ...                   ...           ...       ...        ...          ...
# 4135  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4136  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4137  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4138  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4139  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#you may use the head() to view only the top five rows of the dataframe
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-09 00:00:00   376000.0       3.0       2.00         1340      1384
# 1  2014-05-09 00:00:00   800000.0       4.0       3.25         3540    159430
# 2  2014-05-09 00:00:00  2238888.0       5.0       6.50         7270    130017
# 3  2014-05-09 00:00:00   324000.0       3.0       2.25          998       904
# 4  2014-05-10 00:00:00   549900.0       5.0       2.75         3060      7015
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     3.0           0     0          3        1340              0      2008
# 1     2.0           0     0          3        3540              0      2007
# 2     2.0           0     0          3        6420            850      2010
# 3     2.0           0     0          3         798            200      2007
# 4     1.0           0     0          5        1600           1460      1979
#
# ...

# %%
df.shape
# Out:
# (4140, 18)

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
#use info() function to view a summary information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4140 entries, 0 to 4139
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4140 non-null   object
#  1   price          4140 non-null   float64
#  2   bedrooms       4140 non-null   float64
#  3   bathrooms      4140 non-null   float64
#  4   sqft_living    4140 non-null   int64
#  5   sqft_lot       4140 non-null   int64
#  6   floors         4140 non-null   float64
#  7   waterfront     4140 non-null   int64
#  8   view           4140 non-null   int64
#  9   condition      4140 non-null   int64
#  10  sqft_above     4140 non-null   int64
#  11  sqft_basement  4140 non-null   int64
#  12  yr_built       4140 non-null   int64
#  13  yr_renovated   4140 non-null   int64
#  14  street         4140 non-null   object
#  15  city           4140 non-null   object
#  16  statezip       4140 non-null   object
# ...

# %%
#use describe() if you want to know or view basic statistical values like mean, standard deviation,
#frequency (count) of the given dataset
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.140000e+03  4140.000000  4140.000000   4140.000000  4.140000e+03
# mean   5.530629e+05     3.400483     2.163043   2143.638889  1.469764e+04
# std    5.836865e+05     0.903939     0.784733    957.481621  3.587684e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.200000e+05     3.000000     1.750000   1470.000000  5.000000e+03
# 50%    4.600000e+05     3.000000     2.250000   1980.000000  7.676000e+03
# 75%    6.591250e+05     4.000000     2.500000   2620.000000  1.100000e+04
# max    2.659000e+07     8.000000     6.750000  10040.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4140.000000  4140.000000  4140.000000  4140.000000  4140.000000
# mean      1.514130     0.007488     0.246618     3.452415  1831.351449
# std       0.534941     0.086219     0.790619     0.678533   861.382947
# ...

# %%
#remove categorical data
df.drop(columns=['date','waterfront','condition','view','yr_renovated','floors', 'yr_built','street','city','statezip','country'],inplace=True)

# %%
#Display the correlation
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

#find the pairwise correlation of all columns in the data frame
#positive values means positive correlation; negative values means negative correlation
#positive correlation --- two variables move in the same direction as one another;
#                         when one variable increases the other variable also increases;
#                         when one variable decreases the other variable also decreases;
#negative correlation --- when one variable increases the other variable decreases;
#                         when one variable decreases the other variable increases;

#df.corr()
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
#perform Exploratory Data Analysis using seaborn pairplot
sns.pairplot(df)

# %%
print(df.columns)
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'sqft_above', 'sqft_basement'],
#       dtype='object')

# %%
#Option 1
#new data set without price column. Note: all categorical data were removed already
X = df.drop(['price'],axis=1)
#dependent value/target variable
y = df['price']

# %%
#Option 2
#Place the data into an X array that contains independent variables (explanatory variable) and y (target variable)
#by enumerating all the columns to be included in the array

#independent values X array does not include the price
X = df[['Area Income','House Age','Number of Rooms','Number of Bedrooms','Area Population']]
#dependent value/target variable y Price
y = df['Price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 6
#       1 #Option 2
#       2 #Place the data into an X array that contains independent variables (explanatory variable) and y (target variable)
#       3 #by enumerating all the columns to be included in the array
#       4
#       5 #independent values X array does not include the price
# ----> 6 X = df[['Area Income','House Age','Number of Rooms','Number of Bedrooms','Area Population']]
#       7 #dependent value/target variable y Price
#       8 y = df['Price']
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
# ...

# %%
X
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  sqft_above  sqft_basement
# 0          3.0       2.00         1340      1384        1340              0
# 1          4.0       3.25         3540    159430        3540              0
# 2          5.0       6.50         7270    130017        6420            850
# 3          3.0       2.25          998       904         798            200
# 4          5.0       2.75         3060      7015        1600           1460
# ...        ...        ...          ...       ...         ...            ...
# 4135       3.0       1.75         1510      6360        1510              0
# 4136       3.0       2.50         1460      7573        1460              0
# 4137       3.0       2.50         3010      7014        3010              0
# 4138       4.0       2.00         2090      6630        1070           1020
# 4139       3.0       2.50         1490      8102        1490              0
#
# [4140 rows x 6 columns]

# %%
y
# Out:
# 0       3.760000e+05
# 1       8.000000e+05
# 2       2.238888e+06
# 3       3.240000e+05
# 4       5.499000e+05
#             ...
# 4135    3.081667e+05
# 4136    5.343333e+05
# 4137    4.169042e+05
# 4138    2.034000e+05
# 4139    2.206000e+05
# Name: price, Length: 4140, dtype: float64

# %%
#split the normalized data using 60:40 as the ratio; but note that in model training 80:20 is recommended
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=10)

# %%
print("Training set", X_train.shape)
print("Testing set", X_test.shape)
# Out:
# Training set (3312, 6)
# Testing set (828, 6)

# %%
#Build the Classifier: import the Linear Regression library
from sklearn.linear_model import LinearRegression

# %%
#create A Linear Regression model
lm = LinearRegression()

# %%
#Train the data model
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#get the intercept
intercept = lm.intercept_

#display the Intercept
print (f"Intercept : {intercept: .2f}")
# Out:
# Intercept :  144077.34

# %%
#get the slope of each independent variable (features)

coeff_df= pd.DataFrame(lm.coef_, X.columns, columns=['Coefficient'])

# %%
#show the coefficient
print (coeff_df)
# Out:
#                 Coefficient
# bedrooms      -63487.620237
# bathrooms       7652.632034
# sqft_living      200.732836
# sqft_lot          -0.527075
# sqft_above        83.885683
# sqft_basement    116.847153

# %%
#Predict house price using the training data
y_pred_train = lm.predict(X_train)
y_pred_train
# Out:
# array([ 693661.63855062,  737592.98054339,  421367.35979286, ...,
#         474503.65025926, 1250918.63493232,  249617.25991466],
#       shape=(3312,))

# %%
#predict the house price from the first training data
print (y_pred_train[0])
# Out:
# 693661.6385506187

# %%
#Predict house price using the test data
y_pred_test = lm.predict(X_test)
y_pred_test
# Out:
# array([ 590594.84586044,  561622.06442988,  382824.10945697,
#         244108.40584457,  552012.79847776,  460053.29182033,
#         588233.94736065,  722538.51809895,  276563.40607521,
#         472888.64399745,  439473.30448284,  558642.4512763 ,
#         594414.62480245,  606436.86785757,  675957.28690097,
#         519531.6552512 ,  761784.10517119,  408370.70274282,
#         742751.24327573,  568903.80321924,  581620.37253214,
#         850008.94734039,  684292.33410028,  333255.73850559,
#         526525.46608212,  372730.33844565,  807071.61475849,
#         428842.6840229 ,  675641.21832679,  680604.62019217,
#         218358.55149319,  525238.83238374, 1942694.1933669 ,
#         987379.62242309,  456234.17789709,  639388.33012825,
#         824349.10191127,  694782.44922671,  261977.92696832,
#         473153.70245706,  260351.66512613,  549419.40364791,
#         573053.28441021,  530487.05283779,  584088.36913563,
# ...

# %%
#Compute and display the predicted against the actual
y_pred_df = pd.DataFrame({'Actual Price': y_test, 'Predicted Price': y_pred_test, 'Difference': y_test-y_pred_test})
y_pred_df[0:20]
# Out:
#       Actual Price  Predicted Price     Difference
# 992       665000.0    590594.845860   74405.154140
# 1943      743000.0    561622.064430  181377.935570
# 2247      451000.0    382824.109457   68175.890543
# 756       353000.0    244108.405845  108891.594155
# 2068      500000.0    552012.798478  -52012.798478
# 2195      170000.0    460053.291820 -290053.291820
# 3071      417000.0    588233.947361 -171233.947361
# 3098      738000.0    722538.518099   15461.481901
# 1094      400000.0    276563.406075  123436.593925
# 3490      975000.0    472888.643997  502111.356003
# 1243      985000.0    439473.304483  545526.695517
# 1123      295000.0    558642.451276 -263642.451276
# 176       510000.0    594414.624802  -84414.624802
# 330       720000.0    606436.867858  113563.132142
# 2851      589950.0    675957.286901  -86007.286901
# 3692      435000.0    519531.655251  -84531.655251
# 237       420000.0    761784.105171 -341784.105171
# ...

# %%
#visualize the difference between actual and prediction results.

import matplotlib.pyplot as plt

#plt.figure(figsize=(10,10))
plt.scatter(y_train, y_pred_train, label= 'Training data',color='b', alpha=0.7)
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], 'r', label='Regression line')


plt.legend()
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %%
#r2 measures how close are the data fitted to the regression line
# r_square answers the question: Is the model is good or bad?

from sklearn.metrics import r2_score

score = r2_score(y_train,y_pred_train) # portion of the variance that can be explained by the training features
print (f"Score: {score*100: .2f}%") #coeff of determination
# Out:
# Score:  16.24%

# %%
#visualize the price using the testing versus predicted data
#plot a regression line
import seaborn as sns
sns.regplot(x=y_test,y= y_pred_test, ci=None)
#sns.regplot(x=y_test,y= y_pred_test, fit_reg=True data=data)
# Out:
# <Axes: xlabel='price'>
