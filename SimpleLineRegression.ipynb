# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = np.random.randint(1,10,size=10)
y = np.random.randint(1,10,size=10)

xMean = np.mean(x)
yMean = np.mean(y)

# %%
#Step 2: Calculate slope (m)
numerator = np.sum((x - xMean) * (y - yMean))
denominator = np.sum((x - xMean) ** 2)
m = numerator / denominator

# Step 3: Calculate intercept (b)
b = yMean - m * xMean

# Step 4: Predict values
y_pred = m * x + b

# Output
print(f"Hours study (x): {x}")
print(f"Exam Scores(y): {y}")

print("Slope (m):", m)
print("Intercept (b):", b)

# Step 5: Plot
plt.scatter(x, y, color='blue', label="Actual data")
plt.plot(x, y_pred, color='red', label="Regression line")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.legend()
plt.show()
# Out:
# Hours study (x): [6 4 5 3 6 4 9 2 6 9]
# Exam Scores(y): [1 5 2 4 6 4 6 9 8 5]
# Slope (m): -0.10330578512396696
# Intercept (b): 5.5578512396694215
